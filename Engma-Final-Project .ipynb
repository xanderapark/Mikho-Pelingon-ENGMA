# %%
#lets bring in pandas
#Lets import NumPy
#Lets import libraries from sklearn
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import datasets
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from statsmodels.graphics.mosaicplot import mosaic
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\njpel\Desktop\Workbook2.csv", sep=",")
df.head()
# Out:
#   State and Year  Year  Population  Total Crime Rate  Violent Crime Rate  \
# 0    alaska 1965  1965      253000           26036.0              1490.0
# 1    alaska 1966  1966      272000           27857.0              1504.0
# 2    alaska 1967  1967      272000           28846.0              1607.0
# 3    alaska 1968  1968      277000           33209.0              1755.0
# 4    alaska 1969  1969      282000           38801.0              2213.0
#
#    Murder  Forcible Rape  Robbery  Aggravated Assault  Property Crime Rate  \
# 0    63.0          178.0    399.0               850.0              24545.0
# 1   129.0          195.0    360.0               820.0              26353.0
# 2    96.0          176.0    353.0               982.0              27239.0
# 3   105.0          217.0    527.0               906.0              31455.0
# 4   106.0          294.0    674.0              1138.0              36589.0
#
#    Burglary  Larceny-Theft  Motor Vehicle Theft  State
# ...

# %%
df.describe()
# Out:
#               Year    Population  Total Crime Rate  Violent Crime Rate  \
# count   414.000000  4.140000e+02        414.000000          414.000000
# mean   1987.500000  6.157977e+06      30314.211594         2751.237923
# std      13.291981  8.149121e+06      36474.766260         2654.633092
# min    1965.000000  2.530000e+05       2011.400000           86.500000
# 25%    1976.000000  1.962000e+06       4496.550000          427.625000
# 50%    1987.500000  4.079000e+06      31403.500000         2235.500000
# 75%    1999.000000  5.769750e+06      48177.500000         4726.000000
# max    2010.000000  3.725396e+07     432510.000000        11197.000000
#
#            Murder  Forcible Rape      Robbery  Aggravated Assault  \
# count  414.000000     414.000000   414.000000          414.000000
# mean    53.025121     220.245652   773.157729         1709.857488
# std     72.892646     223.980929   850.889826         1721.113003
# ...

# %%
plot = df.plot(y="Population",kind="hist")
plt.title('Population')
plot.set_xlabel("Population")
plot.set_ylabel("Frequency of Population")
# Out:
# Text(0,0.5,'Frequency of Population')

# %%
plot = df.plot(y="Total Crime Rate",kind="hist")
plt.title('Histogram of Total Crime Rate')
plot.set_xlabel("Total Crime Rate")
plot.set_ylabel("Frequency of Total Crime Rate")
# Out:
# Text(0,0.5,'Frequency of Total Crime Rate')

# %%
plot = df.plot(y="Violent Crime Rate",kind="hist")
plt.title('Histogram of Violent Crime Rate')
plot.set_xlabel("Violent Crime Rate")
plot.set_ylabel("Frequency of Violent Crime Rate")
# Out:
# Text(0,0.5,'Frequency of Violent Crime Rate')

# %%
plot = df.plot(y="Murder",kind="hist")
plt.title('Histogram of Murder')
plot.set_xlabel("Murder")
plot.set_ylabel("Frequency of Murder")
# Out:
# Text(0,0.5,'Frequency of Murder')

# %%
plot = df.plot(y="Forcible Rape",kind="hist")
plt.title('Histogram of Forcible Rape')
plot.set_xlabel("Forcible Rape")
plot.set_ylabel("Frequency of Forcible Rape")
# Out:
# Text(0,0.5,'Frequency of Forcible Rape')

# %%
plot = df.plot(y="Robbery",kind="hist")
plt.title('Histogram of Robbery')
plot.set_xlabel("Robbery")
plot.set_ylabel("Frequency of Robbery")
# Out:
# Text(0,0.5,'Frequency of Robbery')

# %%
plot = df.plot(y="Aggravated Assault",kind="hist")
plt.title('Histogram of Aggravated Assault')
plot.set_xlabel("Aggravated Assault")
plot.set_ylabel("Frequency of Aggravated Assault")
# Out:
# Text(0,0.5,'Frequency of Aggravated Assault')

# %%
plot = df.plot(y="Property Crime Rate",kind="hist")
plt.title('Histogram of Property Crime Rate')
plot.set_xlabel("Property Crime Rate")
plot.set_ylabel("Frequency of Property Crime Rate")
# Out:
# Text(0,0.5,'Frequency of Property Crime Rate')

# %%
plot = df.plot(y="Burglary",kind="hist")
plt.title('Histogram of Burglary')
plot.set_xlabel("Burglary")
plot.set_ylabel("Frequency of Burglary")
# Out:
# Text(0,0.5,'Frequency of Burglary')

# %%
plot = df.plot(y="Larceny-Theft",kind="hist")
plt.title('Histogram of Larceny-Theft')
plot.set_xlabel("Larceny-Theft")
plot.set_ylabel("Frequency of Larceny-Theft")
# Out:
# Text(0,0.5,'Frequency of Larceny-Theft')

# %%
plot = df.plot(y="Motor Vehicle Theft",kind="hist")
plt.title('Histogram of Motor Vehicle Theft')
plot.set_xlabel("Motor Vehicle Theft")
plot.set_ylabel("Frequency of Motor Vehicle Theft")
# Out:
# Text(0,0.5,'Frequency of Motor Vehicle Theft')

# %%
df.plot(x='Population', y='Murder', style='o')  
plt.title('Population vs Murder')  
plt.xlabel('Population')  
plt.ylabel('Murder')  
plt.show()

df['Population'].corr(df['Murder'])
# Out:
# 0.06377839431346022

# %%
df.plot(x='Population', y='Forcible Rape', style='o')  
plt.title('Population vs Forcible Rape')  
plt.xlabel('Population')  
plt.ylabel('Forcible Rape')  
plt.show()

df['Population'].corr(df['Forcible Rape'])
# Out:
# 0.04902917435195079

# %%
df.plot(x='Population', y='Robbery', style='o')  
plt.title('Population vs Robbery')  
plt.xlabel('Population')  
plt.ylabel('Robbery')  
plt.show()

df['Population'].corr(df['Robbery'])
# Out:
# 0.647302059000489

# %%
df.plot(x='Population', y='Aggravated Assault', style='o')  
plt.title('Population vs Aggravated Assault')  
plt.xlabel('Population')  
plt.ylabel('Aggravated Assault')  
plt.show()

df['Population'].corr(df['Aggravated Assault'])
# Out:
# 0.34466320111627735

# %%
df.plot(x='Population', y='Burglary', style='o')  
plt.title('Population vs Burglary')  
plt.xlabel('Population')  
plt.ylabel('Burglary')  
plt.show()

df['Population'].corr(df['Burglary'])
# Out:
# 0.2294685032915684

# %%
df.plot(x='Population', y='Larceny-Theft', style='o')  
plt.title('Population vs Larceny-Theft')  
plt.xlabel('Population')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Population'].corr(df['Larceny-Theft'])
# Out:
# 0.09738789451366335

# %%
df.plot(x='Population', y='Motor Vehicle Theft', style='o')  
plt.title('Population vs Motor Vehicle Theft')  
plt.xlabel('Population')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Population'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.451619968514636

# %%
df.plot(x='Population', y='State', style='o')  
plt.title('Population vs State')  
plt.xlabel('Population')  
plt.ylabel('State')  
plt.show()

df['Population'].corr(df['State'])
# Out:
# 0.030758496084357444

# %%
df.plot(x='Population', y='Year', style='o')  
plt.title('Population vs Year')  
plt.xlabel('Population')  
plt.ylabel('Year')  
plt.show()

# %%
df.plot(x='Murder', y='Forcible Rape', style='o')  
plt.title('Murder vs Forcible Rape')  
plt.xlabel('Murder')  
plt.ylabel('Forcible Rape')  
plt.show()

df['Murder'].corr(df['Forcible Rape'])
# Out:
# 0.6292469939927038

# %%
df.plot(x='Murder', y='Robbery', style='o')  
plt.title('Murder vs Robbery')  
plt.xlabel('Murder')  
plt.ylabel('Robbery')  
plt.show()

df['Murder'].corr(df['Robbery'])
# Out:
# 0.43423390063394246

# %%
df.plot(x='Murder', y='Aggravated Assault', style='o')  
plt.title('Murder vs Aggravated Assault')  
plt.xlabel('Murder')  
plt.ylabel('Aggravated Assault')  
plt.show()

df['Murder'].corr(df['Aggravated Assault'])
# Out:
# 0.6005067556204

# %%
df.plot(x='Murder', y='Burglary', style='o')  
plt.title('Murder vs Burglary')  
plt.xlabel('Murder')  
plt.ylabel('Burglary')  
plt.show()

df['Murder'].corr(df['Burglary'])
# Out:
# 0.4852727436545267

# %%
df.plot(x='Murder', y='Larceny-Theft', style='o')  
plt.title('Murder vs Larceny-Theft')  
plt.xlabel('Murder')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Murder'].corr(df['Larceny-Theft'])
# Out:
# 0.48951414820661954

# %%
df.plot(x='Murder', y='Motor Vehicle Theft', style='o')  
plt.title('Murder vs Motor Vehicle Theft')  
plt.xlabel('Murder')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Murder'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.4548487759646702

# %%
df.plot(x='Murder', y='State', style='o')  
plt.title('Murder vs State')  
plt.xlabel('Murder')  
plt.ylabel('State')  
plt.show()

# %%
df.plot(x='Murder', y='Year', style='o')  
plt.title('Murder vs Year')  
plt.xlabel('Murder')  
plt.ylabel('Year')  
plt.show()

# %%
df.plot(x='Forcible Rape', y='Robbery', style='o')  
plt.title('Forcible Rape vs Robbery')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Robbery')  
plt.show()

df['Forcible Rape'].corr(df['Robbery'])
# Out:
# 0.6011789495462642

# %%
df.plot(x='Forcible Rape', y='Aggravated Assault', style='o')  
plt.title('Forcible Rape vs Aggravated Assault')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Aggravated Assault')  
plt.show()

df['Forcible Rape'].corr(df['Aggravated Assault'])
# Out:
# 0.8295276344417343

# %%
df.plot(x='Forcible Rape', y='Property Crime Rate', style='o')  
plt.title('Forcible Rape vs Property Crime Rate')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Property Crime Rate')  
plt.show()

df['Forcible Rape'].corr(df['Property Crime Rate'])
# Out:
# 0.7859953892188836

# %%
df.plot(x='Forcible Rape', y='Burglary', style='o')  
plt.title('Forcible Rape vs Burglary')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Burglary')  
plt.show()

df['Forcible Rape'].corr(df['Burglary'])
# Out:
# 0.6682176352979278

# %%
df.plot(x='Forcible Rape', y='Larceny-Theft', style='o')  
plt.title('Forcible Rape vs Larceny-Theft')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Forcible Rape'].corr(df['Larceny-Theft'])
# Out:
# 0.8075431911508484

# %%
df.plot(x='Forcible Rape', y='Motor Vehicle Theft', style='o')  
plt.title('Forcible Rape vs Motor Vehicle Theft')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Forcible Rape'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.6985189376742246

# %%
df.plot(x='Forcible Rape', y='State', style='o')  
plt.title('Forcible Rape vs State')  
plt.xlabel('Forcible Rape')  
plt.ylabel('State')  
plt.show()

# %%
df.plot(x='Forcible Rape', y='Year', style='o')  
plt.title('Forcible Rape vs Year')  
plt.xlabel('Forcible Rape')  
plt.ylabel('Year')  
plt.show()

# %%
df.plot(x='Robbery', y='Aggravated Assault', style='o')  
plt.title('Robbery vs Aggravated Assault')  
plt.xlabel('Robbery')  
plt.ylabel('Aggravated Assault')  
plt.show()

df['Robbery'].corr(df['Aggravated Assault'])
# Out:
# 0.7676807011468808

# %%
df.plot(x='Robbery', y='Burglary', style='o')  
plt.title('Robbery vs Burglary')  
plt.xlabel('Robbery')  
plt.ylabel('Burglary')  
plt.show()

df['Robbery'].corr(df['Burglary'])
# Out:
# 0.8076194045908709

# %%
df.plot(x='Robbery', y='Larceny-Theft', style='o')  
plt.title('Robbery vs Larceny-Theft')  
plt.xlabel('Robbery')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Robbery'].corr(df['Larceny-Theft'])
# Out:
# 0.7339995416732206

# %%
df.plot(x='Robbery', y='Motor Vehicle Theft', style='o')  
plt.title('Robbery vs Motor Vehicle Theft')  
plt.xlabel('Robbery')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Robbery'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.8480925994087362

# %%
df.plot(x='Robbery', y='State', style='o')  
plt.title('Robbery vs State')  
plt.xlabel('Robbery')  
plt.ylabel('State')  
plt.show()

# %%
df.plot(x='Robbery', y='Year', style='o')  
plt.title('Robbery vs Year')  
plt.xlabel('Robbery')  
plt.ylabel('Year')  
plt.show()

# %%
df.plot(x='Aggravated Assault', y='Burglary', style='o')  
plt.title('Aggravated Assault vs Burglary')  
plt.xlabel('Aggravated Assault')  
plt.ylabel('Burglary')  
plt.show()

df['Aggravated Assault'].corr(df['Burglary'])
# Out:
# 0.6454061107357137

# %%
df.plot(x='Aggravated Assault', y='Larceny-Theft', style='o')  
plt.title('Aggravated Assault vs Larceny-Theft')  
plt.xlabel('Aggravated Assault')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Aggravated Assault'].corr(df['Larceny-Theft'])
# Out:
# 0.6955937373196671

# %%
df.plot(x='Aggravated Assault', y='Motor Vehicle Theft', style='o')  
plt.title('Aggravated Assault vs Motor Vehicle Theft')  
plt.xlabel('Aggravated Assault')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Aggravated Assault'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.7073091898521549

# %%
df.plot(x='Aggravated Assault', y='State', style='o')  
plt.title('Aggravated Assault vs State')  
plt.xlabel('Aggravated Assault')  
plt.ylabel('State')  
plt.show()

# %%
df.plot(x='Aggravated Assault', y='Year', style='o')  
plt.title('Aggravated Assault vs Year')  
plt.xlabel('Aggravated Assault')  
plt.ylabel('Year')  
plt.show()

# %%
df.plot(x='Burglary', y='Larceny-Theft', style='o')  
plt.title('Burglary vs Larceny-Theft')  
plt.xlabel('Burglary')  
plt.ylabel('Larceny-Theft')  
plt.show()

df['Burglary'].corr(df['Larceny-Theft'])
# Out:
# 0.9017208501518968

# %%
df.plot(x='Burglary', y='Motor Vehicle Theft', style='o')  
plt.title('Burglary vs Motor Vehicle Theft')  
plt.xlabel('Burglary')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Burglary'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.805626694516618

# %%
df.plot(x='Larceny-Theft', y='Motor Vehicle Theft', style='o')  
plt.title('Larceny-Theft vs Motor Vehicle Theft')  
plt.xlabel('Larceny-Theft')  
plt.ylabel('Motor Vehicle Theft')  
plt.show()

df['Larceny-Theft'].corr(df['Motor Vehicle Theft'])
# Out:
# 0.847582227524382

# %%
df.plot(x='Larceny-Theft', y='State', style='o')  
plt.title('Larceny-Theft vs State')  
plt.xlabel('Larceny-Theft')  
plt.ylabel('State')  
plt.show()

df['Larceny-Theft'].corr(df['State'])
# Out:
# -0.7191421984273034

# %%
df.plot(x='Population', y='Total Crime Rate', style='o')  
plt.title('Population vs Total Crime Rate')  
plt.xlabel('Population')  
plt.ylabel('Total Crime Rate')  
plt.show()

df['Population'].corr(df['Total Crime Rate'])
# Out:
# 0.10147462198100156

# %%
df.plot(x='Population', y='Violent Crime Rate', style='o')  
plt.title('Population vs Violent Crime Rate')  
plt.xlabel('Population')  
plt.ylabel('Violent Crime Rate')  
plt.show()

df['Population'].corr(df['Violent Crime Rate'])
# Out:
# 0.4381234314755347

# %%
df.plot(x='Population', y='Property Crime Rate', style='o')  
plt.title('Population vs Property Crime Rate')  
plt.xlabel('Population')  
plt.ylabel('Property Crime Rate')  
plt.show()

df['Population'].corr(df['Property Crime Rate'])
# Out:
# 0.17729454088100102

# %%
df.plot(x='Violent Crime Rate', y='Property Crime Rate', style='o')  
plt.title('Violent Crime Rate vs Property Crime Rate')  
plt.xlabel('Violent Crime Rate')  
plt.ylabel('Property Crime Rate')  
plt.show()

df['Violent Crime Rate'].corr(df['Property Crime Rate'])
# Out:
# 0.7921990037636123

# %%
dfp = df[['Population', 'Total Crime Rate']]
dfp = dfp.dropna()
X = dfp.iloc[:, :-1].values  
y = dfp.iloc[:, 1].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
print('Regressor intercept:', regressor.intercept_) 
print('Regressor Coefficient:', regressor.coef_)
# Out:
# Regressor intercept: 26140.354056843047
# Regressor Coefficient: [0.00052352]

# %%
y_pred = regressor.predict(X_test)  
dfp = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
dfp
# Out:
#       Actual     Predicted
# 0     3262.4  29373.150874
# 1    48653.0  43033.152894
# 2    50477.0  26806.934853
# 3     5382.9  29176.744080
# 4     4631.5  29178.314626
# 5     3067.9  28986.707945
# 6    70087.0  37603.249908
# 7    61966.0  26324.631520
# 8    62459.0  26419.911345
# 9     5858.3  29061.163370
# 10    3780.0  29420.712259
# 11   39388.0  28099.349137
# 12    3597.6  28640.406616
# 13   72475.0  26619.370759
# 14    5322.3  29279.353122
# 15   48481.0  28366.865568
# 16    5896.1  28641.885024
# 17   67726.0  42044.755590
# 18   58980.0  26353.424874
# 19   45329.0  26556.025381
# 20    4757.8  29188.261421
# 21  432510.0  26461.792587
# 22    5409.0  29167.320800
# 23   25823.0  27993.075486
# 24   64131.0  36855.669744
# 25    3726.7  28923.362567
# 26   74823.0  26645.379010
# 27    7471.3  27954.858853
# 28    3536.9  28172.117795
# 29    4498.2  29198.208216
# ..       ...           ...
# 53    4169.4  29228.572116
# 54   66901.0  36727.408441
# ...

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 26441.19624015632
# Mean Squared Error: 2535059254.8915024
# Root Mean Squared Error: 50349.371941380785

# %%
dfp = df[['Violent Crime Rate', 'Property Crime Rate']]
dfp = dfp.dropna()
X2 = dfp.iloc[:, :-1].values  
y2 = dfp.iloc[:, 1].values
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=0)  
regressor = LinearRegression()  
regressor.fit(X2_train, y2_train) 
print('Regressor intercept:', regressor.intercept_) 
print('Regressor Coefficient:', regressor.coef_)
# Out:
# Regressor intercept: 8109.860280280944
# Regressor Coefficient: [6.32499434]

# %%
y2_pred = regressor.predict(X2_test)  
dfp = pd.DataFrame({'Actual': y2_test, 'Predicted': y2_pred})  
dfp
# Out:
#      Actual     Predicted
# 0    2711.5  11594.932163
# 1   40671.0  58602.290116
# 2   47998.0  24270.220825
# 3    4994.2  10568.385581
# 4    4106.8  11428.584812
# 5    2903.9   9147.159352
# 6   63027.0  52764.320338
# 7   56568.0  42252.179741
# 8   56755.0  44187.628009
# 9    5345.0  11356.479876
# 10   3459.6  10159.158447
# 11  35197.0  34617.911569
# 12   3323.6   9842.908730
# 13  69578.0  26433.368890
# 14   4586.2  12765.688616
# 15  42157.0  48109.124502
# 16   5345.0  11595.564662
# 17  56827.0  77045.973618
# 18  54548.0  36142.235206
# 19  44467.0  13555.680409
# 20   4219.6  11513.972235
# 21  37597.0  43871.378292
# 22   4983.7  10799.880374
# 23  22322.0  30253.665473
# 24  58724.0  42309.104690
# 25   3469.1   9739.178823
# 26  71828.0  27053.218336
# 27   6861.2  11968.739329
# 28   3382.5   9086.439407
# 29   3961.2  11506.382242
# ..      ...           ...
# 53   3738.4  10835.932842
# 54  61715.0  40911.280940
# 55   3547.1  10056.061039
# ...

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y2_test, y2_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y2_test, y2_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y2_test, y2_pred)))
# Out:
# Mean Absolute Error: 10039.242179479163
# Mean Squared Error: 175286905.0908271
# Root Mean Squared Error: 13239.596107541465
